# %% [markdown]
# # Lecture Thirteen
# ## Numerical Methods for Initial Value Problems
#
# # Jupyter Notebook can export as RISE slides, interactive slides!
#
# In this lecture we will obtain approximations to initial value problems
#
# $$y' = f(t,y), \,\,\,t > t_0,\,\,\, y(t_0) = y_0.$$
# ![IMG_20180727_114752.jpg](attachment:IMG_20180727_114752.jpg)

# %%
x=4;
y=x+2
print(y)
# Out:
# 6

# %% [markdown]
# If $a\neq 0$ and $ax^2+bx+c=0$ then
# $$x=\frac{-b\pm \sqrt{b^2-4ac}}{2a}$$

# %%
from IPython.display import IFrame
IFrame('https://arxiv.org/pdf/1406.2661.pdf', width=800, height=450)
# Out:
#         <iframe
#             width="800"
#             height="450"
#             src="https://arxiv.org/pdf/1406.2661.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('mJeNghZXtMo', width=800, height=300)

# %% [markdown]
# * a list of papers
# * paper one [stablemidpoint](files/SomePDFs/stablemidpoint.pdf)#jupyternotebook link firefox only
# * paper one [stablemidpoint](./SomePDFs/stablemidpoint.pdf) #jupyterlab link
